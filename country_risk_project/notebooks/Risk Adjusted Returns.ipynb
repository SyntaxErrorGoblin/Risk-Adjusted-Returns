# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Download 3-month Treasury bill data and convert to monthly returns
tbill = yf.download("^IRX", start="2013-12-31", end="2023-12-31")
tbill_monthly = tbill.resample('ME').last()['Close'] / 100 / 12  # Annual rate to monthly
tbill_monthly = tbill_monthly.dropna()
# Drop first row to align with etf_returns (which starts from the first return, not the first price)
tbill_monthly = tbill_monthly.iloc[1:]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Download ETF data and convert to monthly returns
# auto_adjust=True ensures we get adjusted close prices that account for dividends and stock splits
etf_full = yf.download(["SPY", "EEM", "FM"], start="2013-12-31", end="2023-12-31", auto_adjust=True)
etf_data = etf_full.xs("Close", level="Price", axis=1)
etf_monthly_prices = etf_data.resample("ME").last()
etf_returns = etf_monthly_prices.pct_change().dropna()
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
# Print shapes for all dataframes/series
print("tbill_monthly shape:", tbill_monthly.shape)
print("etf_returns shape:", etf_returns.shape)
# Out:
# tbill_monthly shape: (121, 1)
# etf_returns shape: (120, 3)

# %%
print("tbill_monthly head:", tbill_monthly.head())
print("etf_returns head:", etf_returns.head())
# Out:
# tbill_monthly head: Ticker          ^IRX
# Date
# 2013-12-31  0.000053
# 2014-01-31  0.000008
# 2014-02-28  0.000036
# 2014-03-31  0.000023
# 2014-04-30  0.000017
# etf_returns head: Ticker           EEM        FM       SPY
# Date
# 2014-01-31 -0.086363  0.001778 -0.035248
# 2014-02-28  0.033778  0.033432  0.045515
# 2014-03-31  0.038754  0.037790  0.008295
# 2014-04-30  0.007803  0.025655  0.006952
# 2014-05-31  0.029518  0.045992  0.023206
