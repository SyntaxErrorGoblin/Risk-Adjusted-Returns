# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Download 3-month Treasury bill data
tbill = yf.download("^IRX", start="2013-01-01", end="2023-12-31")

# Convert annual yield to daily return
tbill_daily_return = (1 + tbill['Close']/100) ** (1/252) - 1
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Get ETF price data, used because my data has start data of 2012
etf_data = yf.download(["SPY", "EEM", "FM"], start="2013-01-01", end="2023-12-31")['Close']
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
# Print shapes for all dataframes/series
print("tbill shape:", tbill.shape)
print("tbill_daily_return shape:", tbill_daily_return.shape)
print("etf_data shape:", etf_data.shape)
# Out:
# tbill shape: (2767, 5)
# tbill_daily_return shape: (2767, 1)
# etf_data shape: (2768, 3)

# %%
print("tbill head:", tbill.head)
print("tbill_daily_return head:", tbill_daily_return.head)
print("etf_data head:", etf_data.head)
# Out:
# tbill head: <bound method NDFrame.head of Price       Close   High    Low   Open Volume
# Ticker       ^IRX   ^IRX   ^IRX   ^IRX   ^IRX
# Date
# 2013-01-02  0.055  0.060  0.050  0.052      0
# 2013-01-03  0.065  0.065  0.063  0.065      0
# 2013-01-04  0.065  0.070  0.060  0.070      0
# 2013-01-07  0.058  0.065  0.055  0.065      0
# 2013-01-08  0.060  0.065  0.060  0.065      0
# ...           ...    ...    ...    ...    ...
# 2023-12-22  5.208  5.210  5.173  5.200      0
# 2023-12-26  5.203  5.223  5.198  5.210      0
# 2023-12-27  5.235  5.235  5.100  5.230      0
# 2023-12-28  5.218  5.228  5.218  5.218      0
# 2023-12-29  5.180  5.208  5.145  5.205      0
#
# [2767 rows x 5 columns]>
# tbill_daily_return head: <bound method NDFrame.head of Ticker          ^IRX
# Date
# 2013-01-02  0.000002
# 2013-01-03  0.000003
# 2013-01-04  0.000003
# 2013-01-07  0.000002
# 2013-01-08  0.000002
# ...              ...
# 2023-12-22  0.000201
# 2023-12-26  0.000201
# 2023-12-27  0.000203
# ...

# %%
etf_returns = etf_data.pct_change().dropna()
print("etf_data returns:", etf_returns.shape)
# Out:
# etf_data returns: (2767, 3)
