# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Download 3-month Treasury bill data and convert to monthly compound returns
tbill_annual = yf.download("^IRX", start="2013-12-31", end="2023-12-31").resample('ME').last()['Close'] / 100
tbill_monthly = (1 + tbill_annual)**(1/12) - 1  # Convert annual rate to monthly compound rate
tbill_monthly = tbill_monthly.iloc[1:]  # Align with etf_returns (drop first price, keep returns)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Download ETF data and convert to monthly returns (auto_adjust=True accounts for dividends)
etf_returns = (yf.download(["SPY", "EEM", "FM"], start="2013-12-31", end="2023-12-31", auto_adjust=True)
               .xs("Close", level="Price", axis=1)
               .resample("ME").last()
               .pct_change()
               .dropna())
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
# Print shapes for all dataframes/series
print("tbill_monthly shape:", tbill_monthly.shape)
print("etf_returns shape:", etf_returns.shape)
# Out:
# tbill_monthly shape: (120, 1)
# etf_returns shape: (120, 3)

# %%
print("tbill_monthly head:", tbill_monthly.head())
print("etf_returns head:", etf_returns.head())
# Out:
# tbill_monthly head: Ticker          ^IRX
# Date
# 2014-01-31  0.000008
# 2014-02-28  0.000036
# 2014-03-31  0.000023
# 2014-04-30  0.000017
# 2014-05-31  0.000025
# etf_returns head: Ticker           EEM        FM       SPY
# Date
# 2014-01-31 -0.086363  0.001778 -0.035248
# 2014-02-28  0.033779  0.033432  0.045516
# 2014-03-31  0.038754  0.037790  0.008295
# 2014-04-30  0.007803  0.025655  0.006952
# 2014-05-31  0.029518  0.045992  0.023206

# %%
# Align risk-free rate to ETF return dates
tbill_aligned = (
    tbill_monthly
    .squeeze()
    .reindex(etf_returns.index)
    .ffill()
)

# Compute excess returns
excess_returns = etf_returns.sub(tbill_aligned, axis=0)

# Annualization factor
ann_factor = 12

# Mean and volatility
mean_annual = etf_returns.mean(axis=0) * ann_factor
vol_annual = etf_returns.std(axis=0) * np.sqrt(ann_factor)

# Excess return mean
mean_excess_annual = excess_returns.mean(axis=0) * ann_factor

# Sharpe ratio: use excess return volatility (not total return volatility)
excess_vol_annual = excess_returns.std(axis=0) * np.sqrt(ann_factor)
sharpe = mean_excess_annual / excess_vol_annual

# Sortino ratio: downside deviation only includes negative excess returns
downside_dev = (
    excess_returns[excess_returns < 0]
    .std(axis=0) * np.sqrt(ann_factor)
)
sortino = mean_excess_annual / downside_dev

# %%
# ETF descriptions
descriptions = {"SPY": "(US large cap)", "EEM": "(emerging)", "FM": "(frontier)"}

# Results table
results_table = pd.DataFrame({
    "Description": [descriptions[etf] for etf in mean_annual.index],
    "Mean Annualized Return": mean_annual,
    "Annualized Volatility": vol_annual,
    "Sharpe Ratio": sharpe,
    "Sortino Ratio": sortino
}).round(4)

print("Risk-Adjusted Return Metrics")
print("=" * 60)
print(results_table)
# Out:
# Risk-Adjusted Return Metrics
# ...
#            Description  Mean Annualized Return  Annualized Volatility  \
# Ticker
# EEM         (emerging)                  0.0333                 0.1751
# FM          (frontier)                  0.0266                 0.1670
# SPY     (US large cap)                  0.1246                 0.1516
#
#         Sharpe Ratio  Sortino Ratio
# Ticker
# EEM           0.1184         0.1947
# FM            0.0838         0.1119
# SPY           0.7388         1.0688

# %%
# Bootstrap Confidence Intervals (10,000 samples)
np.random.seed(0)
n_boot = 10000

def bootstrap_ratios(returns, rf_rate):
    """Bootstrap Sharpe and Sortino ratios."""
    n = len(returns)
    sharpe_boot, sortino_boot = [], []
    for _ in range(n_boot):
        idx = np.random.choice(n, n, replace=True)
        boot_r, boot_rf = returns.iloc[idx], rf_rate.iloc[idx]
        boot_excess = boot_r - boot_rf
        mean_excess = boot_excess.mean() * 12
        excess_vol = boot_excess.std() * np.sqrt(12)
        sharpe_boot.append(mean_excess / excess_vol if excess_vol > 0 else np.nan)
        # Downside deviation: only negative excess returns
        boot_negative = boot_excess[boot_excess < 0]
        dd = boot_negative.std() * np.sqrt(12) if len(boot_negative) > 0 else np.nan
        sortino_boot.append(mean_excess / dd if dd > 0 and not np.isnan(dd) else np.nan)
    return np.array(sharpe_boot), np.array(sortino_boot)

# Calculate bootstrap distributions
boot_results = {etf: bootstrap_ratios(etf_returns[etf], tbill_aligned) for etf in etf_returns.columns}

# Confidence intervals
ci_table = pd.DataFrame({
    'Description': [descriptions[etf] for etf in etf_returns.columns],
    'Sharpe': [f"{sharpe[etf]:.4f}" for etf in etf_returns.columns],
    'Sharpe 95% CI': [f"[{np.percentile(boot_results[etf][0], [2.5, 97.5])[0]:.4f}, "
                      f"{np.percentile(boot_results[etf][0], [2.5, 97.5])[1]:.4f}]" for etf in etf_returns.columns],
    'Sortino': [f"{sortino[etf]:.4f}" for etf in etf_returns.columns],
    'Sortino 95% CI': [f"[{np.percentile(boot_results[etf][1], [2.5, 97.5])[0]:.4f}, "
                       f"{np.percentile(boot_results[etf][1], [2.5, 97.5])[1]:.4f}]" for etf in etf_returns.columns]
}, index=etf_returns.columns)

print("Bootstrap Confidence Intervals (95%)")
print("=" * 90)
print(ci_table)
# Out:
# Bootstrap Confidence Intervals (95%)
# ...
#            Description  Sharpe      Sharpe 95% CI Sortino     Sortino 95% CI
# Ticker
# EEM         (emerging)  0.1184  [-0.5119, 0.7336]  0.1947  [-0.8052, 1.3710]
# FM          (frontier)  0.0838  [-0.5201, 0.7495]  0.1119  [-0.6726, 1.2668]
# SPY     (US large cap)  0.7388   [0.1107, 1.4230]  1.0688   [0.1644, 2.2548]

# %%
# Hypothesis Tests: Bootstrap Difference Tests
def diff_test(samples1, samples2):
    diff = samples1 - samples2
    return {'Mean Difference': diff.mean(), 'P-value': (diff <= 0).mean(), 'Significant (p < 0.05)': (diff <= 0).mean() < 0.05}

# Generate all pairwise comparisons via loop
etfs = list(etf_returns.columns)
comparisons = [
    {'Comparison': f"{etf1} vs {etf2}", 'Metric': metric, 
     'samples1': boot_results[etf1][0 if metric == 'Sharpe' else 1],
     'samples2': boot_results[etf2][0 if metric == 'Sharpe' else 1]}
    for i, etf1 in enumerate(etfs)
    for etf2 in etfs[i+1:]
    for metric in ['Sharpe', 'Sortino']
]

comp_table = pd.DataFrame([
    {'Comparison': c['Comparison'], 'Metric': c['Metric'], **diff_test(c['samples1'], c['samples2'])} 
    for c in comparisons
])
comp_table['Mean Difference'] = comp_table['Mean Difference'].round(4)
comp_table['P-value'] = comp_table['P-value'].round(4)

print("\nHypothesis Tests (H0: First ≤ Second, H1: First > Second)")
print("=" * 70)
print(comp_table.to_string(index=False))
# Out:
# Hypothesis Tests (H0: First ≤ Second, H1: First > Second)
# ...
# Comparison  Metric  Mean Difference  P-value  Significant (p < 0.05)
#  EEM vs FM  Sharpe           0.0180   0.4761                   False
#  EEM vs FM Sortino           0.0492   0.4659                   False
# EEM vs SPY  Sharpe          -0.6393   0.9195                   False
# EEM vs SPY Sortino          -0.9077   0.8836                   False
#  FM vs SPY  Sharpe          -0.6574   0.9232                   False
#  FM vs SPY Sortino          -0.9568   0.9109                   False
